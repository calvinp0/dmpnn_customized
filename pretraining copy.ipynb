# %%
from pathlib import Path

from lightning import pytorch as pl
from lightning.pytorch.callbacks import ModelCheckpoint
import pandas as pd

from chemprop import data, featurizers, models, nn

# %%
from pathlib import Path

# Where to persist all your .sdf files
OUTPUT_SDF_DIR = Path("/home/calvin/code/chemprop_original/transition_sdf_files")
OUTPUT_SDF_DIR.mkdir(parents=True, exist_ok=True)

# %%
import tempfile
from rdkit import Chem
from rdkit.Chem import SDWriter


from rdkit import Chem

def save_mol_to_sdf(
    mol: Chem.Mol,
    formula: str,
    rxn: str,
    cfg: str,
    split: str = "train"
) -> Path:
    """Saves an RDKit Mol to a persistent SDF file in OUTPUT_SDF_DIR."""
    # embed properties
    mol.SetProp("mol_type", "ts")
    mol.SetProp("type", "ts")
    mol.SetProp("reaction", rxn)
    mol.SetProp("formula", formula)
    mol.SetProp("config", cfg)
    mol.SetProp("split", split)

    # construct a deterministic filename
    filename = OUTPUT_SDF_DIR / f"{formula}__{rxn}__{cfg}.sdf"
    writer = Chem.SDWriter(str(filename))
    writer.write(mol)
    writer.close()
    return filename

# %%
from rdkit.Chem import GetPeriodicTable


def get_expected_valence(atom):
    ptable = GetPeriodicTable()
    return ptable.GetDefaultValence(atom.GetAtomicNum())

# %%
from rdkit import Chem
import numpy as np


def add_bonds_by_distance(mol, atomic_numbers, positions, threshold_scale=1.2):
    """Adds bonds to an RDKit mol based on interatomic distances and covalent radii."""
    from rdkit.Chem import rdchem
    from periodictable import elements  # pip install periodictable

    conf = mol.GetConformer()
    N = len(atomic_numbers)

    for i in range(N):
        for j in range(i + 1, N):
            pos_i = np.array(conf.GetAtomPosition(i))
            pos_j = np.array(conf.GetAtomPosition(j))
            dist = np.linalg.norm(pos_i - pos_j)

            r_i = elements[atomic_numbers[i]].covalent_radius
            r_j = elements[atomic_numbers[j]].covalent_radius
            threshold = (r_i + r_j) * threshold_scale

            if dist < threshold:
                try:
                    mol.AddBond(i, j, order=rdchem.BondType.SINGLE)
                except:
                    pass  # skip if already bonded or error

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import rdMolTransforms
import random


def get_random_dihedral_with_angle(mol: Chem.Mol, return_sincos: bool = True):
    """
    Returns a single randomly sampled dihedral tuple and its angle.

    Parameters
    ----------
    mol : Chem.Mol
        Molecule with 3D coordinates (must have conformer).
    return_sincos : bool
        If True, returns (sin, cos). If False, returns angle in radians.

    Returns
    -------
    tuple[int, int, int, int], np.ndarray or float
        Dihedral atom indices and the angle (either sin/cos or float).
        Returns None if no valid dihedral found.
    """
    conf = mol.GetConformer()
    dihedrals = []

    for bond in mol.GetBonds():
        j = bond.GetBeginAtomIdx()
        k = bond.GetEndAtomIdx()

        # neighbors excluding the bonded partner
        nbrs_j = [
            a.GetIdx() for a in mol.GetAtomWithIdx(j).GetNeighbors() if a.GetIdx() != k
        ]
        nbrs_k = [
            a.GetIdx() for a in mol.GetAtomWithIdx(k).GetNeighbors() if a.GetIdx() != j
        ]

        for i in nbrs_j:
            for l in nbrs_k:
                try:
                    angle_deg = rdMolTransforms.GetDihedralDeg(conf, i, j, k, l)
                    angle_rad = np.deg2rad(angle_deg)
                    if return_sincos:
                        angle = np.array(
                            [np.sin(angle_rad), np.cos(angle_rad)], dtype=np.float32
                        )
                    else:
                        angle = angle_rad
                    dihedrals.append(((i, j, k, l), angle))
                except:
                    continue  # some atoms might be invalid (e.g., linear or overlapping)

    if not dihedrals:
        return None  # no valid dihedral
    return random.choice(dihedrals)

# %%
SINGLE_BOND_LENGTH = {
    "Br_Br": 2.29,
    "Br_Cr": 1.94,
    "Br_H": 1.41,
    "C_C": 1.54,
    "C_Cl": 1.77,
    "C_F": 1.35,
    "C_H": 1.09,
    "C_I": 2.13,
    "C_N": 1.47,
    "C_O": 1.43,
    "C_P": 1.87,
    "C_S": 1.81,
    "C_Si": 1.86,
    "Cl_Cl": 1.99,
    "Cl_H": 1.27,
    "Cl_N": 1.75,
    "Cl_Si": 2.03,
    "Cl_P": 2.03,
    "Cl_S": 2.07,
    "F_F": 1.42,
    "F_H": 0.92,
    "F_P": 1.57,
    "F_S": 1.56,
    "F_Si": 1.56,
    "F_Xe": 1.90,
    "H_H": 1.0,
    "H_I": 1.61,
    "H_N": 1.04,
    "H_O": 0.96,
    "H_P": 1.42,
    "H_S": 1.34,
    "H_Si": 1.48,
    "I_I": 2.66,
    "N_N": 1.45,
    "N+1_N+1": 1.81,
    "N_O": 1.44,
    "N+1_O-1": 1.2,
    "O_O": 1.48,
    "O_P": 1.63,
    "O_S": 1.58,
    "O_Si": 1.66,
    "P_P": 2.21,
    "S_S": 2.05,
    "Si_Si": 2.35,
}


def get_single_bond_length(
    symbol_1: str,
    symbol_2: str,
    charge_1: int = 0,
    charge_2: int = 0,
) -> float:
    """
    Get an approximate for a single bond length between two elements.

    Args:
        symbol_1 (str): Symbol 1.
        symbol_2 (str): Symbol 2.
        charge_1 (int, optional): The partial charge of the atom represented by ``symbol_1``.
        charge_2 (int, optional): The partial charge of the atom represented by ``symbol_2``.

    Returns: float
        The estimated single bond length in Angstrom.
    """
    if charge_1 and charge_2:
        symbol_1 = f"{symbol_1}{'+' if charge_1 > 0 else ''}{charge_1}"
        symbol_2 = f"{symbol_2}{'+' if charge_2 > 0 else ''}{charge_2}"
    bond1, bond2 = "_".join([symbol_1, symbol_2]), "_".join([symbol_2, symbol_1])
    if bond1 in SINGLE_BOND_LENGTH.keys():
        return SINGLE_BOND_LENGTH[bond1]
    if bond2 in SINGLE_BOND_LENGTH.keys():
        return SINGLE_BOND_LENGTH[bond2]
    return 2.5

# %%
# def log_degree_zero_hydrogens(mol, context_str=None):
#     conf = mol.GetConformer()
#     for idx, atom in enumerate(mol.GetAtoms()):
#         if atom.GetSymbol() == "H" and atom.GetDegree() == 0:
#             pos = conf.GetAtomPosition(idx)
#             msg = (
#                 f"[DEG0-H] Atom idx={idx}, pos=({pos.x:.2f}, {pos.y:.2f}, {pos.z:.2f})"
#             )
#             if context_str:
#                 msg += f" | {context_str}"
#             print(msg)

# %%
# def resolve_floating_hydrogens(mol, atomic_numbers, positions, bond_length_table=None):
#     """
#     For degree-zero H atoms, assign to nearest heavy atom with open valence.

#     Args:
#         mol (Chem.RWMol): The molecule (should be editable, i.e. RWMol).
#         atomic_numbers (list[int]): Atomic numbers (Z) for each atom.
#         positions (np.ndarray): Shape (N, 3), 3D positions for each atom.
#         bond_length_table (dict): Optional; mapping like ('C', 'H') -> 1.09.

#     Returns:
#         fixed (int): Number of hydrogens fixed.
#     """
#     from rdkit.Chem import GetPeriodicTable

#     ptable = GetPeriodicTable()
#     N = len(atomic_numbers)
#     conf = mol.GetConformer()
#     fixed = 0

#     # Find degree-zero H atoms
#     deg0_H = [
#         i
#         for i, a in enumerate(mol.GetAtoms())
#         if a.GetSymbol() == "H" and a.GetDegree() == 0
#     ]
#     heavy_indices = [i for i, a in enumerate(mol.GetAtoms()) if a.GetSymbol() != "H"]

#     for hi in deg0_H:
#         h_pos = positions[hi]
#         # Collect distances to all heavy atoms
#         distances = []
#         for ci in heavy_indices:
#             c_atom = mol.GetAtomWithIdx(ci)
#             c_pos = positions[ci]
#             dist = np.linalg.norm(h_pos - c_pos)
#             # Get bond threshold for this pair
#             c_sym = c_atom.GetSymbol()
#             h_sym = "H"
#             if bond_length_table:
#                 key1, key2 = f"{c_sym}_{h_sym}", f"{h_sym}_{c_sym}"
#                 bond_length = bond_length_table.get(
#                     key1, bond_length_table.get(key2, 1.1)
#                 )
#             else:
#                 bond_length = 1.1  # default C–H
#             if dist < bond_length * 1.25:
#                 expected = ptable.GetDefaultValence(c_atom.GetAtomicNum())
#                 current = c_atom.GetExplicitValence()
#                 deficit = expected - current
#                 if deficit > 0:
#                     distances.append((dist, ci, deficit))

#         if distances:
#             # Sort by distance, take the closest heavy atom with open valence
#             distances.sort()
#             dist, ci, deficit = distances[0]
#             mol.AddBond(hi, ci, Chem.rdchem.BondType.SINGLE)
#             print(
#                 f"[FIXED] Bonded floating H (idx={hi}) to {mol.GetAtomWithIdx(ci).GetSymbol()} (idx={ci}) at d={dist:.2f}Å."
#             )
#             fixed += 1
#         else:
#             print(f"[UNFIXED] Floating H (idx={hi}) could not be attached.")

#     return fixed

# %%
# def build_rdkit_mol_from_h5_with_bonds(atomic_numbers, positions, threshold_scale=1.1):
#     """Create an RDKit mol with inferred bonds using a bond length reference table."""
#     from periodictable import elements

#     mol = Chem.RWMol()
#     atom_indices = []
#     symbols = [elements[int(z)].symbol for z in atomic_numbers]

#     for z in atomic_numbers:
#         atom = Chem.Atom(int(z))
#         idx = mol.AddAtom(atom)
#         atom_indices.append(idx)

#     # Distance-based bond addition using bond length table
#     N = len(atomic_numbers)
#     for i in range(N):
#         for j in range(i + 1, N):
#             pos_i = positions[i]
#             pos_j = positions[j]
#             dist = np.linalg.norm(pos_i - pos_j)

#             # Lookup single bond length for these two elements
#             l_ref = get_single_bond_length(symbols[i], symbols[j])
#             threshold = l_ref * threshold_scale

#             if symbols[i] == "H" or symbols[j] == "H":
#                 fudge = 1.2
#                 threshold = l_ref * fudge

#             if dist < threshold:
#                 try:
#                     mol.AddBond(i, j, Chem.rdchem.BondType.SINGLE)
#                 except Exception:
#                     pass

#     mol = mol.GetMol()  # Convert to readonly Mol

#     # Add conformer
#     conf = Chem.Conformer(len(atomic_numbers))
#     for i, pos in enumerate(positions):
#         conf.SetAtomPosition(i, Chem.rdGeometry.Point3D(*pos))
#     mol.AddConformer(conf, assignId=True)

#     return mol

# %%
# import h5py
# from pathlib import Path

# all_data = []


# def is_suspicious(mol):
#     for atom in mol.GetAtoms():
#         sym = atom.GetSymbol()
#         val = atom.GetExplicitValence()
#         if (
#             (sym == "C" and val > 4)
#             or (sym == "N" and val > 4)
#             or (sym == "O" and val > 2)
#         ):
#             return True
#     return False


# with h5py.File("/home/calvin/Downloads/Transition1x.h5", "r") as f:
#     for split in ["train"]:
#         for formula in f[split]:
#             for rxn in f[split][formula]:
#                 for cfg in f[split][formula][rxn]:
#                     try:
#                         cfg_group = f[split][formula][rxn][cfg]
#                         if not isinstance(cfg_group, h5py.Group):
#                             continue
#                         if "transition" not in cfg.lower():
#                             continue

#                         atomic_numbers = cfg_group["atomic_numbers"][()]
#                         positions_all = cfg_group["positions"][()]
#                         if len(positions_all.shape) != 3 or positions_all.shape[0] == 0:
#                             print(
#                                 f"[SKIP] positions shape invalid: {positions_all.shape}"
#                             )
#                             continue

#                         positions = positions_all[0]

#                         mol = build_rdkit_mol_from_h5_with_bonds(
#                             atomic_numbers, positions
#                         )
#                         resolve_floating_hydrogens(
#                             mol,
#                             atomic_numbers,
#                             positions,
#                             bond_length_table=SINGLE_BOND_LENGTH,
#                         )
#                         log_degree_zero_hydrogens(mol, f"{formula}/{rxn}/{cfg}")

#                         # Log explicit valence BEFORE sanitize
#                         for i, atom in enumerate(mol.GetAtoms()):
#                             try:
#                                 val = atom.GetExplicitValence()
#                             except Exception:
#                                 val = "ERR"
#                             print(
#                                 f"Atom {i}: {atom.GetSymbol()} degree={atom.GetDegree()} valence={val}"
#                             )

#                         # Sanitize
#                         problem = False
#                         try:
#                             Chem.SanitizeMol(mol)
#                         except Exception as e:
#                             print(f"[SanitizeFail] {formula}/{rxn}/{cfg}: {e}")
#                             problem = True

#                         if mol is None or mol.GetNumAtoms() < 4 or is_suspicious(mol):
#                             print(f"[SKIP or Suspicious] {formula}/{rxn}/{cfg}")
#                             for i, atom in enumerate(mol.GetAtoms()):
#                                 try:
#                                     val = atom.GetExplicitValence()
#                                 except Exception:
#                                     val = "ERR"
#                                 print(
#                                     f"  Atom {i}: {atom.GetSymbol()} degree={atom.GetDegree()} valence={val}"
#                                 )
#                             Chem.MolToMolFile(
#                                 mol, f"suspicious_{formula}_{rxn}_{cfg}.mol"
#                             )
#                             continue
#                         result = get_random_dihedral_with_angle(mol, return_sincos=True)
#                         if result is None:
#                             print(
#                                 f"[SKIP] No dihedral found: formula={formula}, rxn={rxn}, cfg={cfg}"
#                             )
#                             continue

#                         _, angle_vec = result
#                         sdf_path = sdf_path = save_mol_to_temp_sdf(
#                             mol, formula, rxn, cfg, split
#                         )

#                         try:
#                             datapoint = data.MoleculeDatapoint.from_sdf(
#                                 sdf_path,
#                                 keep_h=True,
#                                 mol_type="ts",
#                                 sanitize=True,
#                                 y=angle_vec,
#                             )
#                             all_data.append(datapoint)
#                         except Exception as e:
#                             print(
#                                 f"[ERROR] Failed to parse SDF: {sdf_path} ({formula}/{rxn}/{cfg}) — {e}"
#                             )

#                     except Exception as e:
#                         print(f"[ERROR] Outer loop error at {formula}/{rxn}/{cfg}: {e}")

# %%
from pathlib import Path


all_data = []
for sdf_file in Path(OUTPUT_SDF_DIR).glob("*.sdf"):
    try:
        dp_temp = data.MoleculeDatapoint.from_sdf(
            str(sdf_file),
            keep_h=True,
            mol_type="ts",
            sanitize=True
        )
        result = get_random_dihedral_with_angle(dp_temp.mol, return_sincos=True)
        if result is None:
            print(f"[SKIP] No dihedral found: {sdf_file}")
            continue
        _, angle_vec = result
        dp = data.MoleculeDatapoint.from_sdf(
            str(sdf_file),
            keep_h=True,
            mol_type="ts",
            sanitize=True,
            y=[angle_vec]
        )
        all_data.append(dp)
        
    except Exception as e:
        print(f"[ERROR] Loading {sdf_file}: {e}")
# `saved` now holds all your previously generated datapoints
# Out:
# [15:41:48] Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 37
# [15:41:48] ERROR: Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 32
# [15:41:48] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:48] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 30
# [15:41:48] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 31
# [15:41:48] ERROR: Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:41:48] Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 40
# [15:41:48] ERROR: Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 43
# [15:41:48] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 37
# [15:41:48] ERROR: Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 39
# [15:41:48] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 46
# [15:41:48] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 35
# [15:41:48] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:48] Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 27
# [15:41:48] ERROR: Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:41:48] Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 33
# [15:41:48] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:48] Explicit valence for atom # 18 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 44
# [15:41:48] ERROR: Explicit valence for atom # 18 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 33
# [15:41:48] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 34
# [15:41:48] ERROR: Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 29
# [15:41:48] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:48] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 41
# [15:41:48] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 31
# [15:41:48] ERROR: Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 39
# [15:41:48] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:48] Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 29
# [15:41:48] ERROR: Explicit valence for atom # 5 N, 4, is greater than permitted
# [15:41:48] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 26
# [15:41:48] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 34
# [15:41:48] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H9NO__rxn6289__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8N2__rxn2231__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn2640__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6N2O__rxn6460__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10N2__rxn8630__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C7H12__rxn9585__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H9NO__rxn9683__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H11N__rxn1997__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H14O__rxn9892__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8N2__rxn6081__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H5NO__rxn3132__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7N3__rxn5259__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C7H12__rxn7800__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO2__rxn7088__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O__rxn0222__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6N2__rxn4284__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H12__rxn3908__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8O__rxn4495__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H9N__rxn9791__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6N2__rxn0870__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H4N2O__rxn0644__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O__rxn8959__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [15:41:48] Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 34
# [15:41:48] ERROR: Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 2 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 26
# [15:41:48] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# [15:41:48] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 37
# [15:41:48] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 39
# [15:41:48] ERROR: Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 5 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 29
# [15:41:48] ERROR: Explicit valence for atom # 5 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 41
# [15:41:48] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 16 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 40
# [15:41:48] ERROR: Explicit valence for atom # 16 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 33
# [15:41:48] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:48] Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 29
# [15:41:48] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:48] Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 36
# [15:41:48] ERROR: Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 16 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 40
# [15:41:48] ERROR: Explicit valence for atom # 16 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 35
# [15:41:48] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:48] Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:48] ERROR: Could not sanitize molecule ending on line 35
# [15:41:48] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 30
# [15:41:49] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 29
# [15:41:49] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 33
# [15:41:49] ERROR: Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 37
# [15:41:49] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 31
# [15:41:49] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 33
# [15:41:49] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 47
# [15:41:49] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 37
# [15:41:49] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 29
# [15:41:49] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 23
# [15:41:49] ERROR: Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 27
# [15:41:49] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O__rxn1475__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H6N2__rxn2774__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10O__rxn3189__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10O2__rxn8720__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H7NO__rxn9035__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H12__rxn2831__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H10O__rxn8575__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7N3__rxn5258__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6N2__rxn0866__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H10O2__rxn4097__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H10O__rxn6424__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H8__rxn3961__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8N2__rxn8319__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O__rxn3148__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H5N3O__rxn5558__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6O2__rxn3698__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O__rxn2469__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H9N__rxn9643__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn3749__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O__rxn2829__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8O2__rxn2658__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C7H14__rxn8640__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H10__rxn0394__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H5N3O__rxn5669__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H3NO2__rxn3151__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H5N3__rxn1373__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8O2__rxn3887__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [15:41:49] Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 32
# [15:41:49] ERROR: Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 2 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 31
# [15:41:49] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 41
# [15:41:49] ERROR: Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 4 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 31
# [15:41:49] ERROR: Explicit valence for atom # 4 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 24
# [15:41:49] ERROR: Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 44
# [15:41:49] ERROR: Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 30
# [15:41:49] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 17 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 41
# [15:41:49] ERROR: Explicit valence for atom # 17 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 23
# [15:41:49] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 37
# [15:41:49] ERROR: Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 25
# [15:41:49] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 31
# [15:41:49] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 33
# [15:41:49] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 27
# [15:41:49] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 33
# [15:41:49] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 36
# [15:41:49] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 40
# [15:41:49] ERROR: Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 37
# [15:41:49] ERROR: Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 26
# [15:41:49] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 38
# [15:41:49] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 38
# [15:41:49] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 30
# [15:41:49] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 39
# [15:41:49] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn4759__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C7H10__rxn9488__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6N2O__rxn8705__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H4N2__rxn3975__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H14__rxn4167__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H7N3__rxn1524__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O__rxn3147__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H11NO__rxn9749__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H4N2__rxn3969__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10O__rxn4452__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H4N2O__rxn0985__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO2__rxn6968__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8O2__rxn3297__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H5NO__rxn0697__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H7NO__rxn6911__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H8O__rxn6617__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H10O__rxn5347__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H9NO__rxn5515__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C2H4N4__rxn3904__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H10__rxn9248__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H10__rxn0008__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H5N3O__rxn8394__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10O2__rxn5401__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [15:41:49] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 32
# [15:41:49] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 28
# [15:41:49] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 36
# [15:41:49] ERROR: Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 35
# [15:41:49] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 33
# [15:41:49] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 28
# [15:41:49] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 31
# [15:41:49] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 42
# [15:41:49] ERROR: Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 37
# [15:41:49] ERROR: Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 25
# [15:41:49] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 39
# [15:41:49] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 31
# [15:41:49] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 20
# [15:41:49] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 37
# [15:41:49] ERROR: Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 28
# [15:41:49] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 43
# [15:41:49] ERROR: Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 38
# [15:41:49] ERROR: Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 35
# [15:41:49] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 2 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 37
# [15:41:49] ERROR: Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 33
# [15:41:49] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 26
# [15:41:49] ERROR: Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 32
# [15:41:49] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 31
# [15:41:49] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 38
# [15:41:49] ERROR: Explicit valence for atom # 14 H, 2, is greater than permitted
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6O3__rxn5946__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H5N3__rxn2262__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O2__rxn8141__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8N2O__rxn4882__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO2__rxn8594__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H9N__rxn0056__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H5N3__rxn10059__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn3660__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H12O__rxn8524__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H9NO__rxn9057__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H10__rxn8951__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O__rxn2378__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H4N2O__rxn4197__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H10O__rxn8079__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn1236__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C2H4N2__rxn3799__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10O__rxn2088__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H5N3__rxn3047__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H12O__rxn5829__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10O2__rxn5392__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10__rxn1333__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H7NO__rxn6232__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H9NO__rxn8818__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8N2O__rxn4985__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO2__rxn5530__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H5NO__rxn0596__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8O2__rxn4351__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn4628__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H9NO__rxn7431__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [15:41:49] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 33
# [15:41:49] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 43
# [15:41:49] ERROR: Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 32
# [15:41:49] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 24
# [15:41:49] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 22
# [15:41:49] ERROR: Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 31
# [15:41:49] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 41
# [15:41:49] ERROR: Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 36
# [15:41:49] ERROR: Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 25
# [15:41:49] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 29
# [15:41:49] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 27
# [15:41:49] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 36
# [15:41:49] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 37
# [15:41:49] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 41
# [15:41:49] ERROR: Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 24
# [15:41:49] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 17 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 43
# [15:41:49] ERROR: Explicit valence for atom # 17 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 32
# [15:41:49] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 27
# [15:41:49] ERROR: Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 31
# [15:41:49] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:49] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 22
# [15:41:49] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H6O2__rxn7410__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H12O__rxn7103__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn1041__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H7NO__rxn9555__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H4N2__rxn2373__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C2H3N3__rxn2805__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6N2O__rxn6645__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H11NO__rxn6756__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H7NO__rxn6708__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H10O2__rxn3547__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H5NO__rxn0768__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6O2__rxn9251__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6O__rxn0410__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H7N__rxn8348__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H9NO__rxn9928__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H12__rxn9013__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H3NO2__rxn2385__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H12O__rxn8172__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn2067__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H6O2__rxn3852__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn1420__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8N2__rxn3112__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C2H6O__rxn2393__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O__rxn0220__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [15:41:49] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 29
# [15:41:49] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 37
# [15:41:49] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 4 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 20
# [15:41:49] ERROR: Explicit valence for atom # 4 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 34
# [15:41:49] ERROR: Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:49] Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:49] ERROR: Could not sanitize molecule ending on line 32
# [15:41:49] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# ...
# [15:41:53] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 34
# [15:41:53] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 24
# [15:41:53] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 32
# [15:41:53] ERROR: Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 25
# [15:41:53] ERROR: Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 2 N, 4, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 32
# [15:41:53] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# [15:41:53] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 34
# [15:41:53] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:53] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 34
# [15:41:53] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 28
# [15:41:53] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:53] Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 30
# [15:41:53] ERROR: Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 29
# [15:41:53] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:53] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 36
# [15:41:53] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 40
# [15:41:53] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 36
# [15:41:53] ERROR: Explicit valence for atom # 13 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 41
# [15:41:53] ERROR: Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 25
# [15:41:53] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6N2O__rxn6025__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO2__rxn5536__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6O3__rxn7127__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8O2__rxn4573__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H9NO__rxn9470__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H2N4__rxn6788__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn1043__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H5NO__rxn4661__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8N2__rxn1863__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H7NO__rxn5585__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O__rxn4593__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H5N3__rxn8858__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6O2__rxn4643__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H5N3__rxn6096__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H8O__rxn7975__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H11N__rxn5009__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H8O2__rxn8139__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H12__rxn2541__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C2H4N4__rxn3447__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6N2__rxn4289__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H9NO__rxn7270__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO2__rxn5531__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8N2O__rxn7829__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C3H5N3__rxn0062__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [15:41:53] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 30
# [15:41:53] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 2 N, 4, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 38
# [15:41:53] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# [15:41:53] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 33
# [15:41:53] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 35
# [15:41:53] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:53] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 28
# [15:41:53] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 37
# [15:41:53] ERROR: Explicit valence for atom # 14 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 28
# [15:41:53] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 33
# [15:41:53] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 28
# [15:41:53] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 29
# [15:41:53] ERROR: Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 26
# [15:41:53] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 31
# [15:41:53] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 38
# [15:41:53] ERROR: Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 31
# [15:41:53] ERROR: Explicit valence for atom # 7 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 32
# [15:41:53] ERROR: Explicit valence for atom # 10 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 30
# [15:41:53] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 25
# [15:41:53] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [15:41:53] Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 37
# [15:41:53] ERROR: Explicit valence for atom # 9 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 31
# [15:41:53] ERROR: Explicit valence for atom # 12 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 37
# [15:41:53] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# [15:41:53] Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 30
# [15:41:53] ERROR: Explicit valence for atom # 11 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 33
# [15:41:53] ERROR: Explicit valence for atom # 6 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 30
# [15:41:53] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10O__rxn1489__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C2H4N4O__rxn8587__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H6O2__rxn7408__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H5NO__rxn2993__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8__rxn2421__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C2H4N4__rxn1822__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn1559__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H10__rxn2319__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn1770__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn2770__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6N2__rxn3953__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C2H4N4__rxn1820__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10O__rxn1384__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn2206__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C6H9N__rxn8509__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H6N2__rxn0850__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H8O2__rxn4678__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C4H7NO__rxn4568__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10O__rxn1455__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H9NO__rxn6735__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [ERROR] Loading /home/calvin/code/chemprop_original/transition_sdf_files/C5H10O__rxn4212__transition_state.sdf: 'NoneType' object has no attribute 'GetProp'
# [15:41:53] Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 37
# [15:41:53] ERROR: Explicit valence for atom # 15 H, 2, is greater than permitted
# [15:41:53] Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 37
# [15:41:53] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [15:41:53] Explicit valence for atom # 8 H, 2, is greater than permitted
# [15:41:53] ERROR: Could not sanitize molecule ending on line 37
# [15:41:53] ERROR: Explicit valence for atom # 8 H, 2, is greater than permitted

# %%
all_data
# Out:
# [MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee12030>, y=[array([ 0.3984862 , -0.91717434], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0623_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee11c40>, y=[array([ 0.9893272 , -0.14571112], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6044_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee11af0>, y=[array([0.4788202, 0.877913 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0082_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee120a0>, y=[array([-0.04122122, -0.99915004], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8723_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee11310>, y=[array([0.5051927 , 0.86300653], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0348_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee12e30>, y=[array([ 0.91080076, -0.41284624], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4615_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee12dc0>, y=[array([0.5585505, 0.8294705], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8353_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee12f80>, y=[array([ 0.3590787, -0.9333073], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9932_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee12ff0>, y=[array([-0.3004546,  0.9537961], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5213_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee12570>, y=[array([-0.10587196, -0.99437976], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3493_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee13140>, y=[array([ 0.5508152, -0.8346272], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3846_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee13290>, y=[array([-0.18652423, -0.98245037], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2845_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee133e0>, y=[array([-0.99999416,  0.00341666], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0520_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee13370>, y=[array([0.9310473 , 0.36489853], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8713_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee13450>, y=[array([ 0.988957  , -0.14820284], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3229_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee13530>, y=[array([-0.9898103, -0.1423925], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1272_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee12490>, y=[array([ 0.04582899, -0.9989493 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4989_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee13840>, y=[array([ 0.96219873, -0.2723482 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6528_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee12ea0>, y=[array([-0.09294625, -0.99567115], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1446_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee135a0>, y=[array([0.05301871, 0.9985935 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5521_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee13990>, y=[array([-0.86233366, -0.5063405 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1555_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee13920>, y=[array([ 0.62229544, -0.7827825 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8241_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee13c30>, y=[array([-0.06183434, -0.99808645], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8445_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee13e60>, y=[array([-0.9288019 ,  0.37057662], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4302_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbee13f40>, y=[array([-0.99978423, -0.020773  ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6377_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0270>, y=[array([-0.88664824,  0.46244454], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4314_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0200>, y=[array([-0.21600588,  0.9763921 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4248_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a00b0>, y=[array([0.07559138, 0.99713886], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn10051_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0120>, y=[array([-4.2643434e-17,  1.0000000e+00], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2625_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0350>, y=[array([0.33927718, 0.94068646], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1188_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0040>, y=[array([1.8621968e-16, 1.0000000e+00], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0460_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0190>, y=[array([ 0.21449398, -0.97672534], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2337_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a03c0>, y=[array([ 0.21135385, -0.9774096 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0267_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a07b0>, y=[array([0.8408258 , 0.54130584], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7765_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0510>, y=[array([ 0.04881594, -0.9988078 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3913_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a06d0>, y=[array([0.9666172 , 0.25622472], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4857_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0740>, y=[array([-0.22235352, -0.9749661 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5187_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0820>, y=[array([ 0.92235166, -0.3863514 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7130_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0b30>, y=[array([ 0.6786739 , -0.73443973], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3718_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0c80>, y=[array([0.33458975, 0.9423639 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2628_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0a50>, y=[array([-0.86247605, -0.50609785], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7867_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a09e0>, y=[array([0.39317635, 0.9194631 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8928_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0cf0>, y=[array([ 0.99294996, -0.11853449], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3623_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1070>, y=[array([0.875744  , 0.48277584], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1237_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1150>, y=[array([0.7971293 , 0.60380864], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5863_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a11c0>, y=[array([0.7870296 , 0.61691517], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1703_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0ac0>, y=[array([ 0.06629662, -0.99779993], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0640_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a0dd0>, y=[array([0.48591876, 0.874004  ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5570_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1310>, y=[array([0.87969714, 0.4755344 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5655_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1380>, y=[array([0.24942833, 0.96839327], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7775_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1620>, y=[array([-0.47146067,  0.8818871 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0692_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a15b0>, y=[array([ 0.23745495, -0.97139853], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4027_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a17e0>, y=[array([ 0.9114373, -0.411439 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9230_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1770>, y=[array([-0.7129735,  0.701191 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0403_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1a10>, y=[array([ 0.11585741, -0.99326587], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0256_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1af0>, y=[array([0.15854876, 0.9873511 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8374_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a13f0>, y=[array([ 0.48215604, -0.87608534], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4669_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a18c0>, y=[array([0.6021024, 0.7984189], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6231_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1bd0>, y=[array([ 0.932029  , -0.36238366], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9937_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a19a0>, y=[array([0.9998638 , 0.01650497], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7720_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1c40>, y=[array([ 0.4719429, -0.8816291], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9866_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1f50>, y=[array([-0.5767295,  0.8169352], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2733_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a20a0>, y=[array([0.06012233, 0.998191  ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4650_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a21f0>, y=[array([-0.05011787,  0.9987433 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5954_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a1ee0>, y=[array([-0.38499147,  0.9229201 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1477_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2340>, y=[array([-0.00461265,  0.9999894 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2885_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2490>, y=[array([-0.05775561, -0.9983308 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8583_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2500>, y=[array([-0.9731664 , -0.23010239], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7713_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a23b0>, y=[array([-0.51466787,  0.8573896 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1570_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a25e0>, y=[array([-0.8350064,  0.5502402], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8758_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2810>, y=[array([-0.88359976,  0.46824294], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2897_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a26c0>, y=[array([-0.8598585 ,  0.51053244], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7486_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2960>, y=[array([-0.57372475,  0.81904817], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0626_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2ab0>, y=[array([-0.85465103, -0.5192028 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9528_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2a40>, y=[array([-0.00485871,  0.9999882 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2966_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2c00>, y=[array([-0.13431862,  0.9909382 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2122_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2c70>, y=[array([-0.07108019, -0.9974706 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9256_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2b90>, y=[array([0.10506424, 0.9944654 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6691_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2570>, y=[array([-0.9225481 ,  0.38588208], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0203_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2730>, y=[array([-0.97171634, -0.23615116], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0350_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2dc0>, y=[array([-0.04853399, -0.99882156], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5201_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2f10>, y=[array([0.8352209 , 0.54991466], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6458_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a3290>, y=[array([-0.44918725,  0.8934376 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8530_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a3060>, y=[array([-0.9050904 ,  0.42521918], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4137_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a3450>, y=[array([0.77705187, 0.62943655], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8458_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a2f80>, y=[array([0.6225891, 0.7825489], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2562_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a35a0>, y=[array([-0.06110859,  0.9981311 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5005_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a3370>, y=[array([ 0.996138  , -0.08780179], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9941_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a31b0>, y=[array([-0.5899239, -0.8074588], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1116_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a38b0>, y=[array([-0.15227275, -0.98833853], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0156_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a3840>, y=[array([ 0.91675603, -0.39944753], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2314_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a3680>, y=[array([0.8281331, 0.5605315], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0441_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a3ae0>, y=[array([ 0.99960935, -0.02794796], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4535_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a3a00>, y=[array([0.99608463, 0.08840477], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2779_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a3d10>, y=[array([0.05159555, 0.9986681 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9823_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a3c30>, y=[array([-0.86015934,  0.5100254 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8434_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a36f0>, y=[array([ 0.9619571 , -0.27320054], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2828_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9a3ed0>, y=[array([ 0.01249408, -0.9999219 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6789_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0120>, y=[array([0.29789233, 0.9545995 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2901_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0040>, y=[array([-0.47992405,  0.87731004], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1988_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0270>, y=[array([-0.94666755,  0.32221192], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0617_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0200>, y=[array([-0.8237064 ,  0.56701654], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7623_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b03c0>, y=[array([-0.0121159,  0.9999266], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6958_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0510>, y=[array([ 6.6473579e-04, -9.9999976e-01], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2968_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0660>, y=[array([ 0.94063336, -0.3394244 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5699_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b04a0>, y=[array([-0.5923649, -0.8056698], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3733_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b00b0>, y=[array([0.36674264, 0.9303224 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9781_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0900>, y=[array([0.12647384, 0.99196994], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9033_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0820>, y=[array([-0.52139497, -0.8533155 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1952_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0ac0>, y=[array([-0.18218791, -0.98326373], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4984_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0740>, y=[array([ 0.2797947, -0.9600599], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9036_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0b30>, y=[array([-0.9971005 , -0.07609662], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2754_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0a50>, y=[array([0.6098714, 0.7925004], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2377_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0e40>, y=[array([0.31401762, 0.9494172 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3097_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0cf0>, y=[array([-0.61756164, -0.7865225 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7629_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0dd0>, y=[array([-0.52312064, -0.8522586 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9020_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1070>, y=[array([-0.09336565, -0.9956319 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4553_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b11c0>, y=[array([-0.,  1.], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8632_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0eb0>, y=[array([0.62909883, 0.77732533], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3939_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1230>, y=[array([0.5476656 , 0.83669734], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9516_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b13f0>, y=[array([-0.08964267,  0.995974  ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1409_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1540>, y=[array([0.9614817 , 0.27486888], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9827_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b0190>, y=[array([-0.20561656,  0.9786326 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4218_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1380>, y=[array([-0.7561929 ,  0.65434873], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3639_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b15b0>, y=[array([ 0.13444093, -0.9909216 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9634_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1770>, y=[array([-0.7433143 , -0.66894233], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6367_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b18c0>, y=[array([-0.89241505,  0.4512155 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0970_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1000>, y=[array([-0.7305585 , -0.68285006], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9707_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b19a0>, y=[array([0.881207  , 0.47273064], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8872_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1b60>, y=[array([0.03723338, 0.9993066 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn10045_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1850>, y=[array([-0.0894031,  0.9959955], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9177_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1e00>, y=[array([-0.22929868, -0.9733561 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1202_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1bd0>, y=[array([0.74151736, 0.67093366], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1743_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1f50>, y=[array([0.8564831, 0.5161751], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2149_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b1c40>, y=[array([ 0.8531495, -0.5216665], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8175_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2180>, y=[array([-0.07549351,  0.9971463 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4163_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2110>, y=[array([-0.25646654, -0.9665531 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6692_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b20a0>, y=[array([-0.9895231 , -0.14437474], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1573_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2340>, y=[array([ 0.5979298, -0.8015485], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5525_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2420>, y=[array([0.37232465, 0.92810255], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7413_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2260>, y=[array([0.35964954, 0.93308747], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9105_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b26c0>, y=[array([-0.27517593, -0.9613939 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3355_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2730>, y=[array([0.65967745, 0.7515488 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0085_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b23b0>, y=[array([-0.91832423, -0.39582905], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2496_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b28f0>, y=[array([ 0.4694302 , -0.88296956], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7698_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2a40>, y=[array([-0.8929241,  0.4502073], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7721_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2b20>, y=[array([-0.30829036, -0.9512923 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7807_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2490>, y=[array([-0.6127212, -0.7902992], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2018_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2b90>, y=[array([-0.5504516, -0.8348671], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3578_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2dc0>, y=[array([-0.01111123, -0.99993825], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9436_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2e30>, y=[array([-0.5292192,  0.8484851], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1170_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2c70>, y=[array([-0.93860525, -0.34499297], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6003_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2d50>, y=[array([ 0.75050634, -0.6608632 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn10036_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b30d0>, y=[array([-0.57958126, -0.81491446], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1960_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b31b0>, y=[array([ 0.45935798, -0.88825125], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7175_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b3290>, y=[array([0.18627828, 0.98249704], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5759_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b3140>, y=[array([0.34298962, 0.93933916], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1745_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b34c0>, y=[array([-0.4322088,  0.9017736], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2358_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b35a0>, y=[array([-0.7117064, -0.7024771], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2981_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b3220>, y=[array([ 0.038991  , -0.99923956], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3035_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2f10>, y=[array([-5.256248e-04, -9.999999e-01], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2587_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b3680>, y=[array([ 0.9681071 , -0.25053668], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3316_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b3610>, y=[array([ 0.31246027, -0.94993085], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3427_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b2500>, y=[array([-0.8333532, -0.5527408], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2668_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b3a70>, y=[array([-0.938401  ,  0.34554833], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5116_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b3840>, y=[array([0.16288516, 0.98664504], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8763_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b3c30>, y=[array([-0.11762291,  0.9930583 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5964_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b3ca0>, y=[array([0.98897374, 0.14809108], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6325_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b3bc0>, y=[array([ 0.62455356, -0.780982  ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4776_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b3990>, y=[array([-0.01877659,  0.9998237 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2416_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b82e0>, y=[array([-0.98061645,  0.19593717], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2592_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8040>, y=[array([-0.05739499,  0.9983516 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5120_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8270>, y=[array([-0.00138736, -0.99999905], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0732_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8200>, y=[array([ 0.78299177, -0.62203205], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3114_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8120>, y=[array([0.96665955, 0.25606498], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6347_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b84a0>, y=[array([0.997648  , 0.06854577], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4425_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8580>, y=[array([-0.9649033 ,  0.26260555], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1364_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8660>, y=[array([-0.9966015 ,  0.08237389], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8749_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8740>, y=[array([-0.98365295,  0.18007466], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9257_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8430>, y=[array([ 0.99490196, -0.10084718], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4416_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b86d0>, y=[array([-0.8568495 ,  0.51556665], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4873_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8190>, y=[array([-0.99756026, -0.06981089], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6701_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8820>, y=[array([-0.19897656, -0.98000425], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3425_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8c10>, y=[array([0.86715615, 0.49803635], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4811_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8ba0>, y=[array([-0.43850562,  0.89872843], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6324_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8dd0>, y=[array([0.43412134, 0.9008544 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4618_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b87b0>, y=[array([ 0.00701193, -0.99997544], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1001_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8f20>, y=[array([ 0.29466683, -0.9556001 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3608_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b9000>, y=[array([0.9404632 , 0.33989558], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0954_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8f90>, y=[array([-0.22887808, -0.9734551 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5163_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b9070>, y=[array([ 0.99886775, -0.04757294], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0423_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b9150>, y=[array([ 0.06446527, -0.99792   ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2214_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b9380>, y=[array([-0.84868217,  0.5289031 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9327_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b94d0>, y=[array([-0.9449403 , -0.32724264], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4428_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b8b30>, y=[array([0.03223474, 0.9994803 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3351_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b9620>, y=[array([-0.1493477 ,  0.98878473], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4790_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b9690>, y=[array([-0.14482689, -0.989457  ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6973_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b97e0>, y=[array([ 0.2323345, -0.9726359], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0578_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe9b9850>, y=[array([0.84148806, 0.54027575], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5413_ts', V_f=None, E_f=None, V_d=None),
# ...
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81a1f0>, y=[array([-0.99987173,  0.01601746], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1967_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81a340>, y=[array([0.11689112, 0.99314475], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7514_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81a420>, y=[array([-0.9433373, -0.3318353], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4317_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81a3b0>, y=[array([ 0.22001527, -0.9754964 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8536_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81a180>, y=[array([ 0.41667494, -0.90905553], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1033_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81a650>, y=[array([-0.9887173 , -0.14979355], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7736_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81a810>, y=[array([ 0.44099662, -0.89750874], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5384_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81a9d0>, y=[array([0.99598604, 0.0895085 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3342_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81a960>, y=[array([-0.7011121,  0.7130511], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8772_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe819ee0>, y=[array([-0.87709117,  0.48032394], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0404_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81aab0>, y=[array([-0.4567777,  0.8895809], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2876_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81ac70>, y=[array([ 0.05097589, -0.9986999 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4702_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81ab20>, y=[array([0.53497887, 0.84486544], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7630_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81ad50>, y=[array([-0.53440577,  0.8452281 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4893_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81a6c0>, y=[array([ 0.8449673, -0.534818 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0944_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81af10>, y=[array([ 0.9900957 , -0.14039427], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2083_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81ac00>, y=[array([ 0.5351201, -0.844776 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9306_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81b140>, y=[array([0.87689894, 0.48067483], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4169_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81b290>, y=[array([ 0.96223253, -0.272229  ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5082_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81b370>, y=[array([0.16957095, 0.985518  ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7142_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81ace0>, y=[array([ 0.20003387, -0.97978896], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1375_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81b300>, y=[array([ 0.12083975, -0.992672  ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3840_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81b3e0>, y=[array([ 0.11457367, -0.99341476], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7915_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81b4c0>, y=[array([-5.2153936e-17,  1.0000000e+00], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0825_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81b6f0>, y=[array([0.18459295, 0.9828151 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4264_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81b680>, y=[array([-0.4444161, -0.8958205], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9340_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81b990>, y=[array([-0.9686858 , -0.24828966], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn0749_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81ba00>, y=[array([-0.48549184,  0.8742412 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1459_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81ba70>, y=[array([-0.03000265, -0.9995498 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3788_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81af80>, y=[array([ 0.9998989, -0.014218 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6670_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81bca0>, y=[array([-0.00804837, -0.99996763], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8373_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81bae0>, y=[array([-0.23493177, -0.97201186], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7216_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81b920>, y=[array([ 0.01196618, -0.9999284 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8978_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe81bc30>, y=[array([-0.05188857,  0.9986529 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8220_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe8283c0>, y=[array([-0.84892774, -0.52850896], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8022_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828190>, y=[array([-0.1962591,  0.9805521], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5317_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828270>, y=[array([-0.5965376, -0.8025851], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5619_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828120>, y=[array([-0.54354596,  0.8393794 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3467_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828430>, y=[array([-0.8447069 ,  0.53522915], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3662_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe8284a0>, y=[array([-0.,  1.], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1704_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe8280b0>, y=[array([-0.10633314,  0.9943306 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1423_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe8285f0>, y=[array([-0.20277248,  0.9792259 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9560_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe8286d0>, y=[array([0.35459897, 0.9350185 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5609_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828890>, y=[array([-0.95988923,  0.28037953], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6748_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828970>, y=[array([-0.532825  , -0.84622544], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5015_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828ac0>, y=[array([0.08762062, 0.9961539 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7601_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828740>, y=[array([-0.9724994 ,  0.23290548], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7785_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828900>, y=[array([0.96520245, 0.26150388], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6177_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828510>, y=[array([ 0.34927785, -0.9370192 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3989_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828b30>, y=[array([ 0.14796638, -0.9889924 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5511_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828f90>, y=[array([0.808929 , 0.5879063], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2871_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828eb0>, y=[array([-0.6931279 ,  0.72081465], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1485_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828f20>, y=[array([ 0.09975027, -0.9950125 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn4282_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe828e40>, y=[array([ 0.36395782, -0.93141544], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6890_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe8292a0>, y=[array([ 0.4461876, -0.8949395], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn6354_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe8289e0>, y=[array([0.99047935, 0.13766131], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn1492_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe8293f0>, y=[array([-0.7116803, -0.7025035], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2104_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe829540>, y=[array([0.5286736, 0.8488252], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn3048_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe829380>, y=[array([-0.946648  , -0.32226935], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8371_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe829150>, y=[array([-0.6655816 , -0.74632514], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7882_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe829310>, y=[array([-0.94069403,  0.3392562 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn9069_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe829620>, y=[array([ 0.3529484, -0.9356428], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8117_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe829690>, y=[array([ 0.21855018, -0.9758257 ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn7515_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe829770>, y=[array([ 0.72258216, -0.691285  ], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn8562_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe829850>, y=[array([-0.1995051, -0.9798968], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn2442_ts', V_f=None, E_f=None, V_d=None),
#  MoleculeDatapoint(mol=<rdkit.Chem.rdchem.Mol object at 0x708bbe829a80>, y=[array([-0.07323409,  0.99731475], dtype=float32)], weight=1.0, gt_mask=None, lt_mask=None, x_d=None, x_phase=None, name='rxn5474_ts', V_f=None, E_f=None, V_d=None),
#  ...]

# %%
mols = [d.mol for d in all_data]  # RDkit Mol objects are use for structure based splits
train_indices, val_indices, test_indices = data.make_split_indices(
    mols, "random", (0.8, 0.1, 0.1), seed=42
)  # unpack the tuple into three separate lists
# Out:
# The return type of make_split_indices has changed in v2.1 - see help(make_split_indices)

# %%
train_data, val_data, test_data = data.split_data_by_indices(
    all_data, train_indices, val_indices, test_indices
)

len(train_data[0]), len(val_data[0]), len(test_data[0])  # 80, 10, 10
# Out:
# (6749, 843, 845)

# %%
featurizer = featurizers.SimpleMoleculeMolGraphFeaturizer()

train_dset = data.MoleculeDataset(train_data[0], featurizer)


val_dset = data.MoleculeDataset(val_data[0], featurizer)


test_dset = data.MoleculeDataset(test_data[0], featurizer)

# %%
num_workers = 6
train_loader = data.build_dataloader(train_dset, num_workers=8)
val_loader = data.build_dataloader(val_dset, num_workers=num_workers, shuffle=False)
test_loader = data.build_dataloader(test_dset, num_workers=num_workers, shuffle=False)

# %%
mp = nn.BondMessagePassing(depth=4, dropout=0.2)

# %%
# agg = nn.MeanAggregation()
norm_agg = nn.NormAggregation()

# %%
import torch
import torch.nn.functional as F
from chemprop.nn.metrics import ChempropMetric
from torch import Tensor


class CircVectorCosine(ChempropMetric):
    r"""
    Cosine‐based loss for 2-D circular vectors.
    For each (sin,cos) pair it computes
        loss = 1 - cosine_similarity(pred_vector, true_vector)
    and then applies your usual masking & weighting.
    """

    def __init__(self, task_weights=None):
        super().__init__(task_weights=task_weights)

    def _calc_unreduced_loss(
        self,
        preds: torch.Tensor,  # (B, out_dim)
        targets: torch.Tensor,  # (B, out_dim)
        mask: torch.Tensor,  # (B, out_dim)
        weights: torch.Tensor,  # (B,) or (B,2T) or (B,T)
        lt_mask: torch.Tensor,
        gt_mask: torch.Tensor,
    ) -> torch.Tensor:
        B, orig_dim = preds.shape

        # how many full (sin,cos) pairs?
        T = orig_dim // 2
        slice_width = 2 * T

        # slice everything down to exactly 2*T columns
        preds = preds[:, :slice_width]
        targets = targets[:, :slice_width]

        mask = mask[:, :slice_width]

        # now reshape safely (B, T, 2)
        preds = preds.view(B, T, 2)

        targets = targets.view(B, T, 2)

        preds = F.normalize(preds, dim=-1)  # guarantee unit length
        targets = F.normalize(targets, dim=-1)

        # vector‐level mask: require both sin & cos valid
        comp_mask = mask.view(B, T, 2).all(dim=-1)  # (B, T)

        # ==== robust weight handling ====
        w = weights

        if w.ndim == 1 and w.numel() == B:

            w = w.unsqueeze(1).expand(B, T)
        elif w.ndim == 2 and w.numel() == B * T:
            w = w.view(B, T)
        elif w.ndim == 2 and w.numel() == B * slice_width:
            w = w.view(B, T, 2).mean(dim=-1)
        else:
            w = torch.tensor(w.mean(), device=w.device).expand(B, T)
        # =================================

        # compute cosine similarity in [-1,1]
        cos_sim = F.cosine_similarity(preds, targets, dim=-1)  # (B, T)

        # loss = 1 - cosine_similarity
        loss = (1.0 - cos_sim) * comp_mask * w  # (B, T)

        return loss


class CosineAngleMetric(ChempropMetric):
    """A metric reporting mean(1-cosine_similarity) across all (sample,task)."""

    def __init__(self, task_weights=None):
        super().__init__(task_weights=task_weights)

    @property
    def alias(self) -> str:
        return "mean_cosine_loss"

    def _calc_unreduced_loss(
        self,
        preds: torch.Tensor,
        targets: torch.Tensor,
        mask: torch.Tensor,
        weights: torch.Tensor,
        lt_mask: torch.Tensor,
        gt_mask: torch.Tensor,
    ) -> torch.Tensor:
        # reuse exactly the same computation as CircVectorCosine
        return CircVectorCosine._calc_unreduced_loss(
            self, preds, targets, mask, weights, lt_mask, gt_mask
        )


class AngularErrorMetric(ChempropMetric):
    """Mean absolute angular error in degrees, reported over B·2T entries."""

    def __init__(self, task_weights=None, in_degrees: bool = True):
        super().__init__(task_weights=task_weights)
        self.in_degrees = in_degrees

    @property
    def alias(self) -> str:
        return "val_maae_deg"

    def _calc_unreduced_loss(
        self,
        preds: Tensor,  # (B, 2T)
        targets: Tensor,  # (B, 2T)
        mask: Tensor,  # (B, 2T)
        weights: Tensor,  # (B,) or (B,T) or (B,2T)
        lt_mask: Tensor,
        gt_mask: Tensor,
    ) -> Tensor:
        B, out_dim = preds.shape
        T = out_dim // 2
        slice_w = 2 * T

        # trim & reshape
        p = preds[:, :slice_w].view(B, T, 2)
        t = targets[:, :slice_w].view(B, T, 2)
        m = mask[:, :slice_w].view(B, T, 2)

        # vector‐level validity mask
        vec_mask = m.all(dim=-1)  # (B, T)

        # angles, difference, wrap, abs
        pred_ang = torch.atan2(p[..., 0], p[..., 1])
        true_ang = torch.atan2(t[..., 0], t[..., 1])
        diff = (pred_ang - true_ang + torch.pi) % (2 * torch.pi) - torch.pi
        err = diff.abs()  # (B, T)
        if self.in_degrees:
            err = err * 180.0 / torch.pi

        # zero out invalid
        err = err * vec_mask  # (B, T)

        # now tile each error into both sin‐ and cos‐slots → (B,T,2)
        err2 = err.unsqueeze(-1).expand(B, T, 2)
        # flatten → (B, 2T)
        return err2.reshape(B, slice_w)

# %%
import torch
from torch import Tensor
from chemprop.nn.predictors import RegressionFFN, AngularRawFFN


class PeriodicRegressionFFN(RegressionFFN):
    """
    A RegressionFFN that predicts (sin θ, cos θ) for each task and
    renormalizes to unit length.
    """

    def __init__(
        self,
        input_dim: int = 300,
        hidden_dim: int = 300,
        n_layers: int = 1,
        dropout: float = 0.0,
        activation: str = "relu",
        n_tasks: int = 1,
        criterion=None,
    ):

        super().__init__(
            input_dim=input_dim,
            hidden_dim=hidden_dim,
            n_layers=n_layers,
            dropout=dropout,
            activation=activation,
            n_tasks=n_tasks,
            criterion=criterion,
        )

    def forward(self, x: Tensor) -> Tensor:
        """
        x: (batch, input_dim)
        returns: (batch, 2 * n_tasks) raw outputs,
                 which we then reshape + normalize.
        """
        raw = self.ffn(x)  # shape (batch, 2 * n_tasks)

        B, twoT = raw.shape
        T = twoT // 2

        # reshape to (batch, T, 2)
        vecs = raw.view(B, T, 2)

        # normalize each 2-vector to unit length
        # norms = torch.norm(vecs, dim=-1, keepdim=True).clamp(min=1e-6)
        # unit = vecs / norms
        unit = vecs

        # flatten back to (batch, 2*T)
        return unit.view(B, 2 * T)


ffn = PeriodicRegressionFFN(
    input_dim=mp.output_dim,
    n_tasks=2,
    dropout=0.2,
    n_layers=3,
    criterion=CircVectorCosine(task_weights=[1.0, 1.0]),
)
ffn = AngularRawFFN(
        n_tasks       = 1,
    input_dim     = mp.output_dim,
    hidden_dim    = 300,
    n_layers      = 2,
    dropout       = 0.10,
)

# %%
from chemprop.nn import metrics

metric_list = [
    AngularErrorMetric(task_weights=[1.0, 1.0]),
    CosineAngleMetric(task_weights=[1.0, 1.0]),
]  # Only the first metric is used for training and early stopping - can provide many though

# %%
metric_list = [nn.metrics.AngularCosine(lam=0.01)]

# %%
batch_norm = True

# %%
dmpnn = models.MPNN(
    mp,
    norm_agg,
    ffn,
    batch_norm,
    metric_list,
    warmup_epochs=0,
    init_lr=3e-4,
    max_lr=3e-4,
    final_lr=3e-4,  # plain Adam
)

# %%
class LossHistoryCallback(pl.Callback):
    def __init__(self):
        super().__init__()
        self.train_losses = []
        self.val_losses = []

    def on_train_epoch_end(self, trainer, pl_module):
        self.train_losses.append(trainer.callback_metrics["train_loss"].cpu().item())

    def on_validation_epoch_end(self, trainer, pl_module):
        self.val_losses.append(trainer.callback_metrics["val_loss"].cpu().item())


# 1) Instantiate callback and pass to Trainer
loss_history = LossHistoryCallback()


class DebugGradCallback(pl.Callback):
    def __init__(self, first_n_steps: int = 3):
        self.first_n_steps = first_n_steps

    # runs after every backward pass – perfect place to look at gradients
    # see Lightning docs, “on_after_backward” hook :contentReference[oaicite:0]{index=0}
    def on_after_backward(self, trainer, pl_module):
        if trainer.global_step < self.first_n_steps:
            print(f"\n— step {trainer.global_step} —")
            for name, p in pl_module.named_parameters():
                if p.requires_grad and p.grad is not None:
                    print(f"{name:40s} ‖grad‖={p.grad.norm().item():.3e}")
            lr = trainer.optimizers[0].param_groups[0]["lr"]
            print(f"current LR = {lr:.3e}")

    # grab the very first batch to inspect mask / targets
    def on_train_batch_start(self, trainer, pl_module, batch, batch_idx):
        if trainer.global_step == 0:
            *_, targets, _, _, _ = batch
            print("target mask unique:", targets.isfinite().unique())

# %%
def _configure_optimizers(self):
    core, head = [], []
    for n, p in self.named_parameters():
        (head if "predictor" in n else core).append(p)

    opt = torch.optim.Adam(
        [{'params': core, 'lr': 3e-4},
         {'params': head, 'lr': 3e-3}],
        weight_decay=1e-4,
    )
    #  Cosine schedule over *trainer.max_epochs*; Lambda defers bind
    sched = torch.optim.lr_scheduler.CosineAnnealingLR(
        opt, T_max=self.trainer.max_epochs, eta_min=1e-5
    )
    return {"optimizer": opt, "lr_scheduler": sched}

# attach cleanly
dmpnn.configure_optimizers = _configure_optimizers.__get__(dmpnn)

# %%
from lightning.pytorch.callbacks import ModelCheckpoint, EarlyStopping

checkpoint_cb = ModelCheckpoint(
    monitor="val/angular-cos",
    mode="min",  # we want smaller angular error
    save_top_k=1,
    filename="best-{epoch:02d}-{val_maae_deg:.2f}",
)

earlystop_cb = EarlyStopping(
    monitor="val/angular-cos",
    mode="min",
    patience=10,  # stop if no improvement in 10 epochs
)

trainer = pl.Trainer(
    max_epochs=30,
    accelerator="auto",
    devices=1,
    callbacks=[checkpoint_cb, earlystop_cb, loss_history, DebugGradCallback()],
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
from torch.optim import Adam
from torch.nn.utils import clip_grad_norm_
import matplotlib.pyplot as plt

mp_dim = dmpnn.message_passing.output_dim

# --- 2. predictor with no hard normalisation ------------------------------
class AngularFFNNoNorm(nn.AngularFFN):
    def forward(self, z):
        y = super(nn.AngularFFN, self).forward(z).view(len(z), 1, 2)
        return y                                # raw outputs (no F.normalize)

head = AngularFFNNoNorm(
    n_tasks=1, input_dim=mp_dim,
    hidden_dim=300, n_layers=2, dropout=0.0, activation="relu"
)
head.vector_target = True

# optional: non-zero init for final layer
last_linear = head.ffn[-1][-1]          # block -1  →  layer -1
torch.nn.init.normal_(last_linear.weight, mean=0.0, std=0.5)
torch.nn.init.normal_(last_linear.bias,   mean=0.0, std=0.1)



dmpnn.predictor = head                     # plug the head in
for p in dmpnn.message_passing.parameters():
    p.requires_grad = True

opt = Adam([
    {"params": dmpnn.message_passing.parameters(), "lr": 3e-4},
    {"params": dmpnn.predictor.parameters(),       "lr": 3e-3},
], weight_decay=1e-4)


lam = 0.01             # soft penalty weight
train_losses, val_losses = [], []

def angular_cos_loss(preds, targets, lam=0.01):
    eps = 1e-8
    norms = preds.norm(dim=-1)
    cos_delta = (preds * targets).sum(-1) / (
        norms * targets.norm(dim=-1) + eps
    )
    cos_term = 1.0 - cos_delta.clamp(-1.0 + 1e-7, 1.0 - 1e-7)
    unit_pen = lam * (norms - 1.0).pow(2)

    # Diagnostics
    if torch.isnan(cos_term).any() or torch.isnan(unit_pen).any():
        print("NaNs detected!")

    return (cos_term + unit_pen).mean(), cos_term, unit_pen, norms

def hybrid_loss(preds, targets, alpha=0.5, lam=0.01):
    eps = 1e-8
    cos_delta = (preds * targets).sum(-1) / (
        preds.norm(dim=-1) * targets.norm(dim=-1) + eps
    )
    cosine = 1.0 - cos_delta.clamp(-1.0 + 1e-7, 1.0 - 1e-7)
    mse = ((preds - targets) ** 2).sum(-1)
    unit_pen = lam * (preds.norm(dim=-1) - 1.0).pow(2)
    return (alpha * cosine + (1 - alpha) * mse + unit_pen).mean()



for epoch in range(30):
    dmpnn.train()
    total_loss = 0

    for batch_idx, batch in enumerate(train_loader):
        opt.zero_grad()
        preds = dmpnn(*batch[:3])
        loss = hybrid_loss(preds, batch[3], alpha=0.5, lam=lam)

        loss.backward()
        clip_grad_norm_(dmpnn.parameters(), max_norm=5.0)
        opt.step()
        total_loss += loss.item()
        # Run only first batch
        if batch_idx == 0:
            with torch.no_grad():
                preds = dmpnn(*batch[:3])
                print("post-init mean‖ŷ‖:", preds.norm(dim=-1).mean().item())
    train_loss = total_loss / len(train_loader)
    train_losses.append(train_loss)

    # Validation
    dmpnn.eval()
    with torch.no_grad():
        total_val_loss = 0
        for batch in val_loader:
            preds = dmpnn(*batch[:3])
            loss = hybrid_loss(preds, batch[3], alpha=0.5, lam=lam)
            total_val_loss += loss.item()
        val_loss = total_val_loss / len(val_loader)
        val_losses.append(val_loss)

    print(f"Epoch {epoch:2d} | Train loss: {train_loss:.4f} | Val loss: {val_loss:.4f}")
# Out:
# post-init mean‖ŷ‖: 8.011380195617676
# Epoch  0 | Train loss: 1.8917 | Val loss: 1.0380
# post-init mean‖ŷ‖: 0.49196380376815796
# Epoch  1 | Train loss: 1.0519 | Val loss: 1.0239
# post-init mean‖ŷ‖: 0.1278185099363327
# Epoch  2 | Train loss: 1.0352 | Val loss: 1.0309
# post-init mean‖ŷ‖: 0.09599997848272324
# Epoch  3 | Train loss: 1.0331 | Val loss: 1.1419
# post-init mean‖ŷ‖: 0.1310463696718216
# Epoch  4 | Train loss: 1.0255 | Val loss: 1.0228
# post-init mean‖ŷ‖: 0.08105972409248352
# Epoch  5 | Train loss: 1.0068 | Val loss: 1.0531
# post-init mean‖ŷ‖: 0.2314944565296173
# Epoch  6 | Train loss: 1.0145 | Val loss: 1.0108
# post-init mean‖ŷ‖: 0.15149596333503723
# Epoch  7 | Train loss: 1.0317 | Val loss: 1.0174
# post-init mean‖ŷ‖: 0.11548784375190735
# Epoch  8 | Train loss: 1.0222 | Val loss: 1.0290
# post-init mean‖ŷ‖: 0.11547130346298218
# Epoch  9 | Train loss: 1.0130 | Val loss: 1.0051
# post-init mean‖ŷ‖: 0.08722399175167084
# Epoch 10 | Train loss: 1.0103 | Val loss: 1.0307
# post-init mean‖ŷ‖: 0.10303685069084167
# Epoch 11 | Train loss: 1.0259 | Val loss: 1.0106
# post-init mean‖ŷ‖: 0.16422924399375916
# Epoch 12 | Train loss: 1.0121 | Val loss: 1.0174
# post-init mean‖ŷ‖: 0.10375091433525085
# Epoch 13 | Train loss: 1.0004 | Val loss: 1.0469
# post-init mean‖ŷ‖: 0.17985963821411133
# Epoch 14 | Train loss: 1.0111 | Val loss: 1.0112
# post-init mean‖ŷ‖: 0.08188055455684662
# Epoch 15 | Train loss: 1.0002 | Val loss: 1.0227
# post-init mean‖ŷ‖: 0.10002216696739197
# Epoch 16 | Train loss: 1.0081 | Val loss: 1.0030
# post-init mean‖ŷ‖: 0.053545668721199036
# Epoch 17 | Train loss: 1.0052 | Val loss: 1.0287
# post-init mean‖ŷ‖: 0.10228513181209564
# Epoch 18 | Train loss: 1.0030 | Val loss: 1.0296
# post-init mean‖ŷ‖: 0.17652477324008942
# Epoch 19 | Train loss: 1.0037 | Val loss: 1.0456
# post-init mean‖ŷ‖: 0.11212125420570374
# Epoch 20 | Train loss: 1.0021 | Val loss: 1.0270
# post-init mean‖ŷ‖: 0.09205116331577301
# Epoch 21 | Train loss: 0.9974 | Val loss: 1.0112
# post-init mean‖ŷ‖: 0.10469476878643036
# Epoch 22 | Train loss: 1.0195 | Val loss: 1.0139
# post-init mean‖ŷ‖: 0.07009421288967133
# Epoch 23 | Train loss: 1.0141 | Val loss: 1.0368
# post-init mean‖ŷ‖: 0.10542359948158264
# Epoch 24 | Train loss: 1.0141 | Val loss: 1.0256
# post-init mean‖ŷ‖: 0.0943555012345314
# Epoch 25 | Train loss: 1.0111 | Val loss: 1.0063
# post-init mean‖ŷ‖: 0.07873949408531189
# Epoch 26 | Train loss: 1.0070 | Val loss: 1.0121
# post-init mean‖ŷ‖: 0.08443431556224823
# Epoch 27 | Train loss: 1.0040 | Val loss: 1.0166
# post-init mean‖ŷ‖: 0.11938245594501495
# Epoch 28 | Train loss: 1.0093 | Val loss: 1.0147
# post-init mean‖ŷ‖: 0.05750041827559471
# Epoch 29 | Train loss: 1.0064 | Val loss: 1.0139

# %%
n_total, n_frozen = 0, 0
for n, p in dmpnn.named_parameters():
    n_total += 1
    if not p.requires_grad and "message_passing" in n:
        print(f"✓ frozen: {n}")
        n_frozen += 1
print(f"{n_frozen}/{n_total} parameters are frozen (message-passing only)")
# Out:
# ✓ frozen: message_passing.W_i.weight
# ✓ frozen: message_passing.W_h.weight
# ✓ frozen: message_passing.W_o.weight
# ✓ frozen: message_passing.W_o.bias
# 4/12 parameters are frozen (message-passing only)

# %%
# subset_loader = data.build_dataloader(
#     torch.utils.data.Subset(train_dset, range(32)), batch_size=32, shuffle=True
# )
trainer.fit(dmpnn, train_loader, val_loader)

# %%
mp_dim = dmpnn.message_passing.output_dim

# --- 2. predictor with no hard normalisation ------------------------------
class AngularFFNNoNorm(nn.AngularFFN):
    def forward(self, z):
        y = super(nn.AngularFFN, self).forward(z).view(len(z), 1, 2)
        return y                                # raw outputs (no F.normalize)

head = AngularFFNNoNorm(
    n_tasks=1, input_dim=mp_dim,
    hidden_dim=300, n_layers=2, dropout=0.0, activation="relu"
)
head.vector_target = True

# optional: non-zero init for final layer
last_linear = head.ffn[-1][-1]          # block -1  →  layer -1
torch.nn.init.normal_(last_linear.weight, mean=0.0, std=0.2)
torch.nn.init.normal_(last_linear.bias,   mean=0.0, std=0.2)


dmpnn.predictor = head                     # plug the head in

# --- 3. tiny 32-sample subset --------------------------------------------


# --- 4. loss  -------------------------------------------------------------
def angular_cos_loss(preds, targets, lam=0.0):
    eps = 1e-8
    cos_delta = (preds * targets).sum(-1) / (
        preds.norm(dim=-1) * targets.norm(dim=-1) + eps
    )
    cosine_term = 1.0 - cos_delta.clamp(-1.0 + 1e-7, 1.0 - 1e-7)
    unit_pen    = lam * (preds.norm(dim=-1) - 1.0).pow(2)
    return (cosine_term + unit_pen).mean(), cosine_term

# --- 5. optimiser: higher LR for the new head -----------------------------
opt = torch.optim.Adam([
    {'params': dmpnn.message_passing.parameters(), 'lr': 3e-4},
    {'params': head.parameters(),                 'lr': 3e-3},
], weight_decay=0.0)

# --- 6. train  ------------------------------------------------------------
dmpnn.train()
step = 0
for epoch in range(200):
    for batch in subset_loader:
        opt.zero_grad()
        preds = dmpnn(*batch[:3])           # bmg, V_d, X_d  → model forward
        lam = 0.01            # start small
        loss, cos_term = angular_cos_loss(preds, batch[3], lam=lam)
        loss.backward()
        opt.step()

        if step % 20 == 0:
            print(f"step {step:4d}  loss {loss.item():.4f}  "
                  f"mean‖ŷ‖ {preds.norm(dim=-1).mean():.3f}  "
                  f"1−cosΔθ {cos_term.mean().item():.3f}")
        step += 1

# %%
# 1  build a brand-new model
head = nn.AngularFFN(
    n_tasks=1, input_dim=mp.output_dim,
    hidden_dim=300, n_layers=2, dropout=0.0, activation="relu"
)
head.vector_target = True      # keep (B,1,2)

torch.nn.init.normal_(head.ffn[-1].weight, mean=0.0, std=0.2)
torch.nn.init.normal_(head.ffn[-1].bias, mean=0.0, std=0.2)

# --- remove hard normalisation ---
def forward_no_norm(self, z):
    y = super(nn.AngularFFN, self).forward(z).view(len(z), 1, 2)
    return y                    # raw outputs
nn.AngularFFN.forward = forward_no_norm

# 2  soft unit-length penalty
def loss_fn_cos(preds, targets):
    cos_delta = (preds * targets).sum(-1) / (
        preds.norm(dim=-1) * targets.norm(dim=-1) + 1e-8
    )
    cosine = 1 - cos_delta.clamp(-1+1e-7, 1-1e-7)   # shape (B,1)
    unit_pen = 0.01 * (preds.norm(dim=-1) - 1).pow(2)   # same shape
    return (cosine + unit_pen).mean()

λ_unit = 0.00          # start at 0 for over-fit test

def angular_cos_loss(preds, targets, lam=λ_unit):
    eps = 1e-8
    cos_delta = (preds * targets).sum(-1) / (
        preds.norm(dim=-1) * targets.norm(dim=-1) + eps
    )
    cosine_term = 1.0 - cos_delta.clamp(-1.0 + 1e-7, 1.0 - 1e-7)
    unit_pen    = lam * (preds.norm(dim=-1) - 1.0).pow(2)
    return (cosine_term + unit_pen).mean()


# 3  optimiser – flat LR, no weight decay
opt = torch.optim.opt.Adam([
    {'params': dmpnn.message_passing.parameters(), 'lr': 3e-4},
    {'params': head.parameters(),                   'lr': 3e-3},
])
# 4  train on the 32-example loader for 300 steps
for epoch in range(200):
    for batch in subset_loader:
        opt.zero_grad()
        preds = dmpnn(batch.bmg)
        # loss  = loss_fn_cos(preds, batch[3])
        # loss = ((preds - batch[3]).pow(2).sum(-1)).mean()
        λ_unit = 0.00        # no penalty
        loss   = angular_cos_loss(preds, batch[3], lam=λ_unit)
        loss.backward()
        opt.step()
        print(f"epoch {epoch} loss {loss.item():.3f}")
        if step % 20 == 0:
        with torch.no_grad():
            print(f"step {step:4d}  loss {loss.item():.4f}  "
                f"mean‖ŷ‖ {preds.norm(dim=-1).mean():.3f}  "
                f"first cosΔθ {(1 - cosine_term.mean()).item():.3f}")

# %%
batch.bmg.y

# %%
import matplotlib.pyplot as plt

train_losses = loss_history.train_losses
# Need to drop the first value as it a sanity check
val_losses = loss_history.val_losses[1:]

assert len(train_losses) == len(val_losses), (
    f"Lengths now match: train={len(train_losses)}, val={len(val_losses)}"
)

epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(12,5))
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.plot(epochs, val_losses,   label='Validation Loss', marker='s')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs. Epoch')
plt.xticks(epochs)
# Rotate x-ticks for better visibility
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
trainer.fit(
    dmpnn,
    train_loader,
    val_loader,
)

# %%
trainer.test(dmpnn, test_loader)

# %%
# print a batch
for batch in train_loader:
    print(batch)
    break

# %%
trainer.predict(dmpnn, train_loader)

# %%
for name, param in dmpnn.named_parameters():
    print(name, param.requires_grad)

# %%
print(dmpnn.training)  # Should be True

# %%
for name, param in dmpnn.named_parameters():
    if param.grad is not None:
        print(f"{name} grad norm: {param.grad.norm().item()}")
    else:
        print(f"{name} has no grad")

# %%
i = 0
for batch in train_loader:
    print(batch)
    break

# %%
batch[0].V

# %%
batch[0].batch

# %%
# batch.batch: tensor of node→mol mapping
for mol_idx in range(batch[0].batch.max().item() + 1):
    mol_mask = batch[0].batch == mol_idx
    print(f"Mol {mol_idx} node features:")
    print(batch[0].V[mol_mask])

# %%
all_data[0].mol

# %%
print(all_data[0].mol.GetAtomWithIdx(1).GetHybridization())
print(all_data[0].mol.GetAtomWithIdx(1).GetSymbol())

# %%
print(all_data[0].mol.GetAtomWithIdx(2).GetHybridization())
print(all_data[0].mol.GetAtomWithIdx(2).GetSymbol())

print(all_data[0].mol.GetAtomWithIdx(4).GetHybridization())
print(all_data[0].mol.GetAtomWithIdx(4).GetSymbol())

# %%
Chem.MolToSmiles(all_data[0].mol)

# %%
for i in range(all_data[0].mol.GetNumAtoms()):
    atom = all_data[0].mol.GetAtomWithIdx(i)
    print(
        f"Atom {i} ({atom.GetSymbol()}): Degree={atom.GetDegree()}, Hybridization={atom.GetHybridization()}"
    )

# %%
for bond in all_data[0].mol.GetBonds():
    print(f"{bond.GetBeginAtomIdx()} - {bond.GetEndAtomIdx()} ({bond.GetBondType()})")
